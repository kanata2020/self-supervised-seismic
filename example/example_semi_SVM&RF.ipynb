# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive/', force_remount=True)

# !ls "/content/drive/My Drive/"
import os
os.chdir("/content/drive/My Drive/")
# Out:
# Mounted at /content/drive/
#  car_detect	  explainer		      passport.jpg   'SZ10 project'
#  detection_XAI	  kfold_results_summary.csv   som_10x10.pkl   test_block
# 'egost project'   msc_project		      SSL

# %%
#data
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as io
from detection_XAI.utils import utils
import cv2
from tensorflow.keras.models import load_model

x_cluster = io.loadmat('./SSL/data/x_cluster.mat')
x_cluster = x_cluster['x_cluster']

# labells

y_cluster = io.loadmat('./SSL/data/y_cluster.mat')
y_cluster = y_cluster['y_cluster']

#pre-processing
from keras.utils import to_categorical

y_cluster_n = to_categorical(y_cluster-1)
x_cluster_n = utils.norml(x_cluster)

x_cluster_stft = utils.batch_stft(x_cluster_n,nfft=128,overlap=0.7)

#reshape input to 64x64
def resize_stft(x_in):
  batch_num = x_in.shape[0]

  # Initialize an empty array to store resized images
  resized_input = np.zeros((batch_num, 64, 64, 3), dtype=np.float32)

  # Loop through each image in the batch and resize
  for i in range(batch_num):
      # Resize each image to (64, 64)
      resized_image = cv2.resize(x_in[i], (64, 64), interpolation=cv2.INTER_LINEAR)

      # Store the resized image in the new array
      resized_input[i] = resized_image


# Now 'resized_images' contains all the images resized to (64, 64, 3) with dtype float32
  return resized_input

resized_x = resize_stft(x_cluster_stft)

saved_encoder_model = load_model("./SSL/model/encoder_4x4x16_v2.h5")
encoded_features = saved_encoder_model.predict(resized_x)
reshaped_features = encoded_features.reshape(encoded_features.shape[0], -1)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score, StratifiedKFold

# Define the models
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
svm_model = SVC(kernel='rbf', C=1.0, random_state=42)

# Define 5-fold cross-validation
#cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Evaluate Random Forest
#rf_scores = cross_val_score(rf_model, reshaped_features, y_cluster.ravel(), cv=cv, scoring='accuracy')
#print(f"Random Forest - Mean Accuracy: {rf_scores.mean():.4f}, Std: {rf_scores.std():.4f}")

# Evaluate SVM
#svm_scores = cross_val_score(svm_model, reshaped_features, y_cluster.ravel(), cv=cv, scoring='accuracy')
#print(f"SVM - Mean Accuracy: {svm_scores.mean():.4f}, Std: {svm_scores.std():.4f}")

# %%
confusion_matrices_array = np.array(confusion_matrices_list)

mean_confusion_matrix = np.mean(confusion_matrices_array, axis=0)
std_confusion_matrix = np.std(confusion_matrices_array, axis=0)


print("Mean Confusion Matrix:")
print(mean_confusion_matrix)
print("\nStandard Deviation Confusion Matrix:")
print(std_confusion_matrix)
# Out:
# Mean Confusion Matrix:
# [[108.8  22.    6.2  50.2]
#  [ 17.6 255.   19.   19.6]
#  [  4.6  19.8 287.2  10. ]
#  [ 12.4   9.6  13.4 244.6]]
#
# Standard Deviation Confusion Matrix:
# [[ 9.06421535  5.4405882   2.22710575  8.81816307]
#  [ 5.42586399 11.3137085   9.54986911  3.72021505]
#  [ 2.33238076  5.6         7.83326241  2.28035085]
#  [ 4.88262225  1.0198039   3.00665928  6.82934843]]

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_recall_fscore_support
import numpy as np

def resultshow(predictions, true_labels):
    target_names = ['quake', 'earthquake', 'rockfall', 'environment noise']

    # Print classification report
    print(classification_report(true_labels, predictions, target_names=target_names))

    # Compute confusion matrix
    confusion_matrices = confusion_matrix(true_labels, predictions)
    print(confusion_matrices)

    # Compute precision, recall, F1-score
    precision, recall, f1, support = precision_recall_fscore_support(true_labels, predictions)

    return confusion_matrices, precision, recall, f1

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
import numpy as np

# K-fold validation (5-fold in this example)
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
data = reshaped_features
labels = y_cluster.flatten()

class_names = ['quake', 'earthquake', 'rockfall', 'noise']
precision_dicts = {class_name: [] for class_name in class_names}
recall_dicts = {class_name: [] for class_name in class_names}
f1_dicts = {class_name: [] for class_name in class_names}
confusion_matrices_list = []
accuracy_list = []

for train_index, test_index in kfold.split(data, labels):
    X_test, X_train = data[train_index], data[test_index]
    y_test, y_train = labels[train_index], labels[test_index]

    # Initialize and train Random Forest or SVM Classifier
    #rf_model = RandomForestClassifier(n_estimators=170, random_state=42)
    #rf_model.fit(X_train, y_train)
    svm_model = SVC(kernel='rbf', C=1.0, random_state=42)
    svm_model.fit(X_train, y_train)

    # Make predictions
    #y_pred = rf_model.predict(X_test)
    y_pred = svm_model.predict(X_test)

    # Compute confusion matrix, precision, recall, and f1-score
    confusion_matrices, precision, recall, f1 = resultshow(y_pred, y_test)
    confusion_matrices_list.append(confusion_matrices)

    # Calculate accuracy for the current fold
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_list.append(accuracy)

    # Update dictionaries for each class
    for class_name in class_names:
        class_index = class_names.index(class_name)
        precision_dicts[class_name].append(precision[class_index])
        recall_dicts[class_name].append(recall[class_index])
        f1_dicts[class_name].append(f1[class_index])

# Calculate mean and std for each class
for class_name in class_names:
    mean_precision = np.mean(precision_dicts[class_name])
    std_precision = np.std(precision_dicts[class_name])

    mean_recall = np.mean(recall_dicts[class_name])
    std_recall = np.std(recall_dicts[class_name])

    mean_f1 = np.mean(f1_dicts[class_name])
    std_f1 = np.std(f1_dicts[class_name])

    # Print mean and std for each class
    print(f"Class {class_name} - Mean Precision: {mean_precision:.3f} ± {std_precision:.3f}")
    print(f"Class {class_name} - Mean Recall: {mean_recall:.3f} ± {std_recall:.3f}")
    print(f"Class {class_name} - Mean F1-score: {mean_f1:.3f} ± {std_f1:.3f}")

# Calculate and print mean and std for accuracy
mean_accuracy = np.mean(accuracy_list)
std_accuracy = np.std(accuracy_list)

print(f"Mean Accuracy: {mean_accuracy:.3f} ± {std_accuracy:.3f}")
# Out:
#                    precision    recall  f1-score   support
#
#             quake       0.79      0.57      0.66       187
#        earthquake       0.85      0.84      0.85       311
#          rockfall       0.92      0.91      0.92       322
# environment noise       0.74      0.90      0.81       280
#
#          accuracy                           0.83      1100
#         macro avg       0.83      0.81      0.81      1100
#      weighted avg       0.83      0.83      0.83      1100
#
# [[106  21   6  54]
#  [ 15 262  10  24]
#  [  4  14 294  10]
#  [  9  10   9 252]]
#                    precision    recall  f1-score   support
#
#             quake       0.68      0.53      0.60       187
#        earthquake       0.82      0.75      0.79       311
#          rockfall       0.84      0.92      0.88       322
# environment noise       0.76      0.85      0.80       280
#
#          accuracy                           0.79      1100
#         macro avg       0.77      0.76      0.77      1100
#      weighted avg       0.79      0.79      0.78      1100
#
# [[100  29  10  48]
#  [ 25 234  32  20]
#  [  4  14 295   9]
#  [ 18   8  15 239]]
#                    precision    recall  f1-score   support
#
#             quake       0.71      0.64      0.67       187
#        earthquake       0.83      0.86      0.84       311
#          rockfall       0.90      0.85      0.87       322
# environment noise       0.77      0.84      0.80       280
#
#          accuracy                           0.81      1100
#         macro avg       0.80      0.80      0.80      1100
#      weighted avg       0.81      0.81      0.81      1100
#
# [[119  14   6  48]
#  [ 23 266   8  14]
#  [  9  29 274  10]
#  [ 17  10  18 235]]
#                    precision    recall  f1-score   support
#
#             quake       0.83      0.53      0.64       188
#        earthquake       0.84      0.84      0.84       311
#          rockfall       0.89      0.88      0.89       321
# environment noise       0.71      0.90      0.80       280
#
#          accuracy                           0.81      1100
#         macro avg       0.82      0.79      0.79      1100
#      weighted avg       0.82      0.81      0.81      1100
#
# [[ 99  19   6  64]
#  [ 11 260  17  23]
#  [  4  20 283  14]
#  [  5  11  12 252]]
#                    precision    recall  f1-score   support
#
#             quake       0.81      0.64      0.71       187
#        earthquake       0.81      0.81      0.81       312
#          rockfall       0.87      0.90      0.89       321
# environment noise       0.80      0.88      0.84       280
#
#          accuracy                           0.83      1100
#         macro avg       0.82      0.81      0.81      1100
#      weighted avg       0.82      0.83      0.82      1100
#
# [[120  27   3  37]
#  [ 14 253  28  17]
#  [  2  22 290   7]
#  [ 13   9  13 245]]
# Class quake - Mean Precision: 0.763 ± 0.059
# Class quake - Mean Recall: 0.581 ± 0.049
# Class quake - Mean F1-score: 0.658 ± 0.037
# Class earthquake - Mean Precision: 0.832 ± 0.014
# Class earthquake - Mean Recall: 0.819 ± 0.036
# Class earthquake - Mean F1-score: 0.825 ± 0.024
# Class rockfall - Mean Precision: 0.883 ± 0.028
# Class rockfall - Mean Recall: 0.893 ± 0.024
# Class rockfall - Mean F1-score: 0.887 ± 0.016
# Class noise - Mean Precision: 0.756 ± 0.029
# Class noise - Mean Recall: 0.874 ± 0.024
# Class noise - Mean F1-score: 0.810 ± 0.014
# Mean Accuracy: 0.814 ± 0.014

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_fscore_support, accuracy_score
import numpy as np

# Define class names
class_names = ['quake', 'earthquake', 'rockfall', 'noise']

# Define different hyperparameter settings for Random Forest
rf_param_grid = [
    {"n_estimators": 100, "max_depth": None, "random_state": 42},
    {"n_estimators": 100, "max_depth": 10, "random_state": 42},
    {"n_estimators": 125, "max_depth": 10, "random_state": 42},
    {"n_estimators": 150, "max_depth": 10, "random_state": 42},
    {"n_estimators": 175, "max_depth": 12, "random_state": 42},
    {"n_estimators": 200, "max_depth": 15, "random_state": 42},
    {"n_estimators": 225, "max_depth": 17, "random_state": 42},
    {"n_estimators": 250, "max_depth": 20, "random_state": 42},
    {"n_estimators": 300, "max_depth": 22, "random_state": 42},
    {"n_estimators": 350, "max_depth": 25, "random_state": 42},
    {"n_estimators": 375, "max_depth": 25, "random_state": 42},
    {"n_estimators": 400, "max_depth": 25, "random_state": 42},
    {"n_estimators": 425, "max_depth": 25, "random_state": 42},
    {"n_estimators": 450, "max_depth": 25, "random_state": 42},
    {"n_estimators": 475, "max_depth": 25, "random_state": 42},
    {"n_estimators": 500, "max_depth": 25, "random_state": 42},
    {"n_estimators": 500, "max_depth": 20, "random_state": 42},
    {"n_estimators": 500, "max_depth": 30, "random_state": 42},
]

# Define different fold numbers to test
fold_list = [3, 5, 10, 20]

# Loop over different folds
for n_splits in fold_list:
    print("="*50)
    print(f"Results for {n_splits}-Fold Cross Validation")
    print("="*50)

    # Loop over different hyperparameter settings
    for params in rf_param_grid:
        print(f"Testing RF with parameters: {params}")

        # Initialize lists to store metrics
        precision_dicts = {class_name: [] for class_name in class_names}
        recall_dicts = {class_name: [] for class_name in class_names}
        f1_dicts = {class_name: [] for class_name in class_names}
        accuracy_list = []

        # Create Stratified K-Fold
        kfold = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

        for train_index, test_index in kfold.split(reshaped_features, y_cluster.flatten()):
            X_train, X_test = reshaped_features[test_index], reshaped_features[train_index]
            y_train, y_test = y_cluster.flatten()[test_index], y_cluster.flatten()[train_index]

            # Train Random Forest with current parameters
            rf_model = RandomForestClassifier(**params)
            rf_model.fit(X_train, y_train-1)

            # Predictions
            y_pred = rf_model.predict(X_test)

            # Compute metrics
            precision, recall, f1, _ = precision_recall_fscore_support(y_test-1, y_pred, labels=range(len(class_names)))
            acc = accuracy_score(y_test-1, y_pred)

            # Store metrics
            accuracy_list.append(acc)
            for i, class_name in enumerate(class_names):
                precision_dicts[class_name].append(precision[i])
                recall_dicts[class_name].append(recall[i])
                f1_dicts[class_name].append(f1[i])

        # Print averaged metrics
        for class_name in class_names:
            mean_precision = np.mean(precision_dicts[class_name])
            mean_recall = np.mean(recall_dicts[class_name])
            mean_f1 = np.mean(f1_dicts[class_name])
            print(f"Class {class_name} - Precision: {mean_precision:.3f}, Recall: {mean_recall:.3f}, F1-score: {mean_f1:.3f}")

        mean_accuracy = np.mean(accuracy_list)
        std_accuracy = np.std(accuracy_list)
        print(f"Overall Accuracy: {mean_accuracy:.3f} ± {std_accuracy:.3f}")
        print("-"*50)
# Out:
# ==================================================
# Results for 3-Fold Cross Validation
# ==================================================
# Testing RF with parameters: {'n_estimators': 100, 'max_depth': None, 'random_state': 42}
# Class quake - Precision: 0.773, Recall: 0.618, F1-score: 0.686
# Class earthquake - Precision: 0.865, Recall: 0.841, F1-score: 0.852
# Class rockfall - Precision: 0.896, Recall: 0.898, F1-score: 0.897
# Class noise - Precision: 0.762, Recall: 0.884, F1-score: 0.818
# Overall Accuracy: 0.831 ± 0.007
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 100, 'max_depth': 10, 'random_state': 42}
# Class quake - Precision: 0.778, Recall: 0.605, F1-score: 0.680
# Class earthquake - Precision: 0.861, Recall: 0.846, F1-score: 0.853
# Class rockfall - Precision: 0.904, Recall: 0.903, F1-score: 0.904
# Class noise - Precision: 0.756, Recall: 0.883, F1-score: 0.814
# Overall Accuracy: 0.831 ± 0.005
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 125, 'max_depth': 10, 'random_state': 42}
# Class quake - Precision: 0.784, Recall: 0.620, F1-score: 0.692
# Class earthquake - Precision: 0.863, Recall: 0.842, F1-score: 0.852
# Class rockfall - Precision: 0.906, Recall: 0.904, F1-score: 0.905
# Class noise - Precision: 0.761, Recall: 0.889, F1-score: 0.820
# Overall Accuracy: 0.834 ± 0.004
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 150, 'max_depth': 10, 'random_state': 42}
# Class quake - Precision: 0.798, Recall: 0.613, F1-score: 0.693
# Class earthquake - Precision: 0.859, Recall: 0.848, F1-score: 0.853
# Class rockfall - Precision: 0.905, Recall: 0.902, F1-score: 0.903
# Class noise - Precision: 0.758, Recall: 0.887, F1-score: 0.817
# Overall Accuracy: 0.834 ± 0.001
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 175, 'max_depth': 12, 'random_state': 42}
# Class quake - Precision: 0.797, Recall: 0.613, F1-score: 0.693
# Class earthquake - Precision: 0.862, Recall: 0.855, F1-score: 0.858
# Class rockfall - Precision: 0.904, Recall: 0.902, F1-score: 0.903
# Class noise - Precision: 0.761, Recall: 0.887, F1-score: 0.819
# Overall Accuracy: 0.836 ± 0.004
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 200, 'max_depth': 15, 'random_state': 42}
# Class quake - Precision: 0.793, Recall: 0.607, F1-score: 0.688
# Class earthquake - Precision: 0.866, Recall: 0.857, F1-score: 0.861
# Class rockfall - Precision: 0.909, Recall: 0.905, F1-score: 0.907
# Class noise - Precision: 0.760, Recall: 0.890, F1-score: 0.820
# Overall Accuracy: 0.837 ± 0.003
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 225, 'max_depth': 17, 'random_state': 42}
# Class quake - Precision: 0.792, Recall: 0.611, F1-score: 0.690
# Class earthquake - Precision: 0.869, Recall: 0.857, F1-score: 0.863
# Class rockfall - Precision: 0.907, Recall: 0.905, F1-score: 0.906
# Class noise - Precision: 0.762, Recall: 0.890, F1-score: 0.821
# Overall Accuracy: 0.838 ± 0.004
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 250, 'max_depth': 20, 'random_state': 42}
# Class quake - Precision: 0.787, Recall: 0.607, F1-score: 0.685
# Class earthquake - Precision: 0.867, Recall: 0.853, F1-score: 0.860
# Class rockfall - Precision: 0.906, Recall: 0.905, F1-score: 0.905
# Class noise - Precision: 0.762, Recall: 0.891, F1-score: 0.822
# Overall Accuracy: 0.836 ± 0.002
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 300, 'max_depth': 22, 'random_state': 42}
# Class quake - Precision: 0.785, Recall: 0.607, F1-score: 0.684
# Class earthquake - Precision: 0.863, Recall: 0.853, F1-score: 0.858
# Class rockfall - Precision: 0.908, Recall: 0.905, F1-score: 0.907
# Class noise - Precision: 0.764, Recall: 0.890, F1-score: 0.822
# Overall Accuracy: 0.836 ± 0.005
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 350, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.787, Recall: 0.607, F1-score: 0.685
# Class earthquake - Precision: 0.866, Recall: 0.853, F1-score: 0.860
# Class rockfall - Precision: 0.911, Recall: 0.903, F1-score: 0.907
# Class noise - Precision: 0.760, Recall: 0.896, F1-score: 0.822
# Overall Accuracy: 0.837 ± 0.004
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 375, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.786, Recall: 0.611, F1-score: 0.687
# Class earthquake - Precision: 0.867, Recall: 0.852, F1-score: 0.859
# Class rockfall - Precision: 0.910, Recall: 0.904, F1-score: 0.907
# Class noise - Precision: 0.760, Recall: 0.893, F1-score: 0.821
# Overall Accuracy: 0.837 ± 0.005
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 400, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.788, Recall: 0.611, F1-score: 0.688
# Class earthquake - Precision: 0.865, Recall: 0.853, F1-score: 0.859
# Class rockfall - Precision: 0.910, Recall: 0.904, F1-score: 0.907
# Class noise - Precision: 0.764, Recall: 0.894, F1-score: 0.824
# Overall Accuracy: 0.837 ± 0.007
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 425, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.791, Recall: 0.615, F1-score: 0.692
# Class earthquake - Precision: 0.865, Recall: 0.856, F1-score: 0.861
# Class rockfall - Precision: 0.912, Recall: 0.902, F1-score: 0.907
# Class noise - Precision: 0.764, Recall: 0.896, F1-score: 0.825
# Overall Accuracy: 0.839 ± 0.007
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 450, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.794, Recall: 0.615, F1-score: 0.693
# Class earthquake - Precision: 0.865, Recall: 0.855, F1-score: 0.860
# Class rockfall - Precision: 0.911, Recall: 0.903, F1-score: 0.907
# Class noise - Precision: 0.763, Recall: 0.894, F1-score: 0.823
# Overall Accuracy: 0.838 ± 0.007
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 475, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.796, Recall: 0.618, F1-score: 0.695
# Class earthquake - Precision: 0.864, Recall: 0.855, F1-score: 0.859
# Class rockfall - Precision: 0.913, Recall: 0.903, F1-score: 0.908
# Class noise - Precision: 0.762, Recall: 0.894, F1-score: 0.823
# Overall Accuracy: 0.839 ± 0.007
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 500, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.791, Recall: 0.615, F1-score: 0.692
# Class earthquake - Precision: 0.865, Recall: 0.851, F1-score: 0.858
# Class rockfall - Precision: 0.910, Recall: 0.903, F1-score: 0.906
# Class noise - Precision: 0.762, Recall: 0.894, F1-score: 0.823
# Overall Accuracy: 0.837 ± 0.007
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 500, 'max_depth': 20, 'random_state': 42}
# Class quake - Precision: 0.791, Recall: 0.615, F1-score: 0.692
# Class earthquake - Precision: 0.865, Recall: 0.851, F1-score: 0.858
# Class rockfall - Precision: 0.910, Recall: 0.903, F1-score: 0.906
# Class noise - Precision: 0.762, Recall: 0.894, F1-score: 0.823
# Overall Accuracy: 0.837 ± 0.007
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 500, 'max_depth': 30, 'random_state': 42}
# Class quake - Precision: 0.791, Recall: 0.615, F1-score: 0.692
# Class earthquake - Precision: 0.865, Recall: 0.851, F1-score: 0.858
# Class rockfall - Precision: 0.910, Recall: 0.903, F1-score: 0.906
# Class noise - Precision: 0.762, Recall: 0.894, F1-score: 0.823
# Overall Accuracy: 0.837 ± 0.007
# --------------------------------------------------
# ==================================================
# Results for 5-Fold Cross Validation
# ==================================================
# Testing RF with parameters: {'n_estimators': 100, 'max_depth': None, 'random_state': 42}
# Class quake - Precision: 0.750, Recall: 0.584, F1-score: 0.655
# Class earthquake - Precision: 0.827, Recall: 0.819, F1-score: 0.823
# Class rockfall - Precision: 0.882, Recall: 0.891, F1-score: 0.885
# Class noise - Precision: 0.756, Recall: 0.862, F1-score: 0.805
# Overall Accuracy: 0.811 ± 0.014
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 100, 'max_depth': 10, 'random_state': 42}
# Class quake - Precision: 0.757, Recall: 0.581, F1-score: 0.655
# Class earthquake - Precision: 0.823, Recall: 0.821, F1-score: 0.822
# Class rockfall - Precision: 0.881, Recall: 0.888, F1-score: 0.884
# Class noise - Precision: 0.755, Recall: 0.862, F1-score: 0.805
# Overall Accuracy: 0.810 ± 0.013
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 125, 'max_depth': 10, 'random_state': 42}
# Class quake - Precision: 0.755, Recall: 0.573, F1-score: 0.649
# Class earthquake - Precision: 0.821, Recall: 0.820, F1-score: 0.820
# Class rockfall - Precision: 0.879, Recall: 0.889, F1-score: 0.883
# Class noise - Precision: 0.755, Recall: 0.863, F1-score: 0.805
# Overall Accuracy: 0.809 ± 0.017
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 150, 'max_depth': 10, 'random_state': 42}
# Class quake - Precision: 0.757, Recall: 0.578, F1-score: 0.653
# Class earthquake - Precision: 0.828, Recall: 0.817, F1-score: 0.823
# Class rockfall - Precision: 0.881, Recall: 0.891, F1-score: 0.885
# Class noise - Precision: 0.754, Recall: 0.869, F1-score: 0.807
# Overall Accuracy: 0.811 ± 0.014
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 175, 'max_depth': 12, 'random_state': 42}
# Class quake - Precision: 0.762, Recall: 0.581, F1-score: 0.657
# Class earthquake - Precision: 0.833, Recall: 0.819, F1-score: 0.826
# Class rockfall - Precision: 0.882, Recall: 0.893, F1-score: 0.887
# Class noise - Precision: 0.755, Recall: 0.871, F1-score: 0.808
# Overall Accuracy: 0.814 ± 0.014
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 200, 'max_depth': 15, 'random_state': 42}
# Class quake - Precision: 0.761, Recall: 0.580, F1-score: 0.656
# Class earthquake - Precision: 0.831, Recall: 0.819, F1-score: 0.825
# Class rockfall - Precision: 0.882, Recall: 0.891, F1-score: 0.886
# Class noise - Precision: 0.755, Recall: 0.874, F1-score: 0.810
# Overall Accuracy: 0.813 ± 0.014
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 225, 'max_depth': 17, 'random_state': 42}
# Class quake - Precision: 0.759, Recall: 0.587, F1-score: 0.660
# Class earthquake - Precision: 0.834, Recall: 0.818, F1-score: 0.826
# Class rockfall - Precision: 0.880, Recall: 0.891, F1-score: 0.885
# Class noise - Precision: 0.756, Recall: 0.872, F1-score: 0.810
# Overall Accuracy: 0.814 ± 0.013
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 250, 'max_depth': 20, 'random_state': 42}
# Class quake - Precision: 0.758, Recall: 0.589, F1-score: 0.661
# Class earthquake - Precision: 0.835, Recall: 0.820, F1-score: 0.827
# Class rockfall - Precision: 0.882, Recall: 0.891, F1-score: 0.886
# Class noise - Precision: 0.757, Recall: 0.871, F1-score: 0.810
# Overall Accuracy: 0.814 ± 0.012
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 300, 'max_depth': 22, 'random_state': 42}
# Class quake - Precision: 0.760, Recall: 0.587, F1-score: 0.661
# Class earthquake - Precision: 0.834, Recall: 0.819, F1-score: 0.827
# Class rockfall - Precision: 0.881, Recall: 0.890, F1-score: 0.885
# Class noise - Precision: 0.757, Recall: 0.875, F1-score: 0.811
# Overall Accuracy: 0.815 ± 0.014
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 350, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.759, Recall: 0.584, F1-score: 0.659
# Class earthquake - Precision: 0.836, Recall: 0.816, F1-score: 0.825
# Class rockfall - Precision: 0.882, Recall: 0.894, F1-score: 0.887
# Class noise - Precision: 0.755, Recall: 0.874, F1-score: 0.809
# Overall Accuracy: 0.814 ± 0.014
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 375, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.762, Recall: 0.584, F1-score: 0.660
# Class earthquake - Precision: 0.836, Recall: 0.817, F1-score: 0.827
# Class rockfall - Precision: 0.882, Recall: 0.894, F1-score: 0.887
# Class noise - Precision: 0.755, Recall: 0.874, F1-score: 0.809
# Overall Accuracy: 0.815 ± 0.013
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 400, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.764, Recall: 0.584, F1-score: 0.661
# Class earthquake - Precision: 0.834, Recall: 0.817, F1-score: 0.825
# Class rockfall - Precision: 0.882, Recall: 0.894, F1-score: 0.887
# Class noise - Precision: 0.754, Recall: 0.874, F1-score: 0.809
# Overall Accuracy: 0.814 ± 0.015
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 425, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.763, Recall: 0.581, F1-score: 0.658
# Class earthquake - Precision: 0.835, Recall: 0.816, F1-score: 0.825
# Class rockfall - Precision: 0.880, Recall: 0.893, F1-score: 0.886
# Class noise - Precision: 0.753, Recall: 0.876, F1-score: 0.809
# Overall Accuracy: 0.814 ± 0.014
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 450, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.763, Recall: 0.582, F1-score: 0.659
# Class earthquake - Precision: 0.836, Recall: 0.818, F1-score: 0.827
# Class rockfall - Precision: 0.882, Recall: 0.893, F1-score: 0.887
# Class noise - Precision: 0.754, Recall: 0.876, F1-score: 0.810
# Overall Accuracy: 0.815 ± 0.014
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 475, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.765, Recall: 0.583, F1-score: 0.660
# Class earthquake - Precision: 0.838, Recall: 0.819, F1-score: 0.828
# Class rockfall - Precision: 0.882, Recall: 0.895, F1-score: 0.888
# Class noise - Precision: 0.754, Recall: 0.875, F1-score: 0.809
# Overall Accuracy: 0.815 ± 0.014
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 500, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.764, Recall: 0.582, F1-score: 0.659
# Class earthquake - Precision: 0.837, Recall: 0.817, F1-score: 0.827
# Class rockfall - Precision: 0.880, Recall: 0.893, F1-score: 0.886
# Class noise - Precision: 0.752, Recall: 0.874, F1-score: 0.808
# Overall Accuracy: 0.814 ± 0.015
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 500, 'max_depth': 20, 'random_state': 42}
# Class quake - Precision: 0.764, Recall: 0.582, F1-score: 0.659
# Class earthquake - Precision: 0.837, Recall: 0.817, F1-score: 0.827
# Class rockfall - Precision: 0.880, Recall: 0.893, F1-score: 0.886
# Class noise - Precision: 0.752, Recall: 0.874, F1-score: 0.808
# Overall Accuracy: 0.814 ± 0.015
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 500, 'max_depth': 30, 'random_state': 42}
# Class quake - Precision: 0.764, Recall: 0.582, F1-score: 0.659
# Class earthquake - Precision: 0.837, Recall: 0.817, F1-score: 0.827
# Class rockfall - Precision: 0.880, Recall: 0.893, F1-score: 0.886
# Class noise - Precision: 0.752, Recall: 0.874, F1-score: 0.808
# Overall Accuracy: 0.814 ± 0.015
# --------------------------------------------------
# ==================================================
# Results for 10-Fold Cross Validation
# ==================================================
# Testing RF with parameters: {'n_estimators': 100, 'max_depth': None, 'random_state': 42}
# Class quake - Precision: 0.682, Recall: 0.553, F1-score: 0.607
# Class earthquake - Precision: 0.804, Recall: 0.781, F1-score: 0.791
# Class rockfall - Precision: 0.861, Recall: 0.870, F1-score: 0.864
# Class noise - Precision: 0.731, Recall: 0.828, F1-score: 0.776
# Overall Accuracy: 0.780 ± 0.015
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 100, 'max_depth': 10, 'random_state': 42}
# Class quake - Precision: 0.682, Recall: 0.552, F1-score: 0.607
# Class earthquake - Precision: 0.804, Recall: 0.781, F1-score: 0.791
# Class rockfall - Precision: 0.861, Recall: 0.870, F1-score: 0.864
# Class noise - Precision: 0.730, Recall: 0.828, F1-score: 0.775
# Overall Accuracy: 0.780 ± 0.014
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 125, 'max_depth': 10, 'random_state': 42}
# Class quake - Precision: 0.682, Recall: 0.556, F1-score: 0.609
# Class earthquake - Precision: 0.807, Recall: 0.777, F1-score: 0.791
# Class rockfall - Precision: 0.859, Recall: 0.871, F1-score: 0.864
# Class noise - Precision: 0.731, Recall: 0.829, F1-score: 0.776
# Overall Accuracy: 0.780 ± 0.018
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 150, 'max_depth': 10, 'random_state': 42}
# Class quake - Precision: 0.684, Recall: 0.551, F1-score: 0.607
# Class earthquake - Precision: 0.805, Recall: 0.780, F1-score: 0.791
# Class rockfall - Precision: 0.858, Recall: 0.871, F1-score: 0.864
# Class noise - Precision: 0.731, Recall: 0.829, F1-score: 0.776
# Overall Accuracy: 0.780 ± 0.017
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 175, 'max_depth': 12, 'random_state': 42}
# Class quake - Precision: 0.687, Recall: 0.548, F1-score: 0.606
# Class earthquake - Precision: 0.808, Recall: 0.781, F1-score: 0.793
# Class rockfall - Precision: 0.861, Recall: 0.872, F1-score: 0.866
# Class noise - Precision: 0.732, Recall: 0.838, F1-score: 0.781
# Overall Accuracy: 0.783 ± 0.018
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 200, 'max_depth': 15, 'random_state': 42}
# Class quake - Precision: 0.690, Recall: 0.548, F1-score: 0.607
# Class earthquake - Precision: 0.809, Recall: 0.782, F1-score: 0.794
# Class rockfall - Precision: 0.863, Recall: 0.873, F1-score: 0.868
# Class noise - Precision: 0.730, Recall: 0.838, F1-score: 0.779
# Overall Accuracy: 0.783 ± 0.017
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 225, 'max_depth': 17, 'random_state': 42}
# Class quake - Precision: 0.691, Recall: 0.548, F1-score: 0.608
# Class earthquake - Precision: 0.808, Recall: 0.781, F1-score: 0.793
# Class rockfall - Precision: 0.864, Recall: 0.873, F1-score: 0.868
# Class noise - Precision: 0.730, Recall: 0.838, F1-score: 0.779
# Overall Accuracy: 0.783 ± 0.018
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 250, 'max_depth': 20, 'random_state': 42}
# Class quake - Precision: 0.692, Recall: 0.547, F1-score: 0.607
# Class earthquake - Precision: 0.809, Recall: 0.781, F1-score: 0.794
# Class rockfall - Precision: 0.863, Recall: 0.872, F1-score: 0.866
# Class noise - Precision: 0.729, Recall: 0.841, F1-score: 0.780
# Overall Accuracy: 0.783 ± 0.016
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 300, 'max_depth': 22, 'random_state': 42}
# Class quake - Precision: 0.692, Recall: 0.545, F1-score: 0.605
# Class earthquake - Precision: 0.808, Recall: 0.782, F1-score: 0.794
# Class rockfall - Precision: 0.863, Recall: 0.872, F1-score: 0.867
# Class noise - Precision: 0.729, Recall: 0.840, F1-score: 0.779
# Overall Accuracy: 0.783 ± 0.018
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 350, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.695, Recall: 0.548, F1-score: 0.609
# Class earthquake - Precision: 0.806, Recall: 0.784, F1-score: 0.794
# Class rockfall - Precision: 0.866, Recall: 0.873, F1-score: 0.868
# Class noise - Precision: 0.730, Recall: 0.839, F1-score: 0.780
# Overall Accuracy: 0.784 ± 0.018
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 375, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.698, Recall: 0.551, F1-score: 0.612
# Class earthquake - Precision: 0.808, Recall: 0.783, F1-score: 0.794
# Class rockfall - Precision: 0.866, Recall: 0.871, F1-score: 0.868
# Class noise - Precision: 0.730, Recall: 0.841, F1-score: 0.780
# Overall Accuracy: 0.784 ± 0.017
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 400, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.698, Recall: 0.553, F1-score: 0.613
# Class earthquake - Precision: 0.811, Recall: 0.783, F1-score: 0.796
# Class rockfall - Precision: 0.866, Recall: 0.872, F1-score: 0.868
# Class noise - Precision: 0.729, Recall: 0.841, F1-score: 0.780
# Overall Accuracy: 0.785 ± 0.017
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 425, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.694, Recall: 0.548, F1-score: 0.608
# Class earthquake - Precision: 0.809, Recall: 0.783, F1-score: 0.795
# Class rockfall - Precision: 0.865, Recall: 0.871, F1-score: 0.867
# Class noise - Precision: 0.728, Recall: 0.841, F1-score: 0.780
# Overall Accuracy: 0.783 ± 0.017
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 450, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.696, Recall: 0.549, F1-score: 0.610
# Class earthquake - Precision: 0.810, Recall: 0.782, F1-score: 0.794
# Class rockfall - Precision: 0.866, Recall: 0.872, F1-score: 0.868
# Class noise - Precision: 0.728, Recall: 0.842, F1-score: 0.780
# Overall Accuracy: 0.784 ± 0.017
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 475, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.696, Recall: 0.551, F1-score: 0.611
# Class earthquake - Precision: 0.808, Recall: 0.781, F1-score: 0.793
# Class rockfall - Precision: 0.867, Recall: 0.872, F1-score: 0.868
# Class noise - Precision: 0.729, Recall: 0.843, F1-score: 0.781
# Overall Accuracy: 0.784 ± 0.018
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 500, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.698, Recall: 0.548, F1-score: 0.610
# Class earthquake - Precision: 0.806, Recall: 0.783, F1-score: 0.794
# Class rockfall - Precision: 0.867, Recall: 0.872, F1-score: 0.868
# Class noise - Precision: 0.730, Recall: 0.842, F1-score: 0.781
# Overall Accuracy: 0.784 ± 0.017
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 500, 'max_depth': 20, 'random_state': 42}
# Class quake - Precision: 0.698, Recall: 0.548, F1-score: 0.610
# Class earthquake - Precision: 0.806, Recall: 0.783, F1-score: 0.794
# Class rockfall - Precision: 0.867, Recall: 0.872, F1-score: 0.868
# Class noise - Precision: 0.730, Recall: 0.842, F1-score: 0.781
# Overall Accuracy: 0.784 ± 0.017
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 500, 'max_depth': 30, 'random_state': 42}
# Class quake - Precision: 0.698, Recall: 0.548, F1-score: 0.610
# Class earthquake - Precision: 0.806, Recall: 0.783, F1-score: 0.794
# Class rockfall - Precision: 0.867, Recall: 0.872, F1-score: 0.868
# Class noise - Precision: 0.730, Recall: 0.842, F1-score: 0.781
# Overall Accuracy: 0.784 ± 0.017
# --------------------------------------------------
# ==================================================
# Results for 20-Fold Cross Validation
# ==================================================
# Testing RF with parameters: {'n_estimators': 100, 'max_depth': None, 'random_state': 42}
# Class quake - Precision: 0.615, Recall: 0.438, F1-score: 0.505
# Class earthquake - Precision: 0.734, Recall: 0.734, F1-score: 0.731
# Class rockfall - Precision: 0.833, Recall: 0.848, F1-score: 0.839
# Class noise - Precision: 0.699, Recall: 0.806, F1-score: 0.747
# Overall Accuracy: 0.735 ± 0.032
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 100, 'max_depth': 10, 'random_state': 42}
# Class quake - Precision: 0.615, Recall: 0.438, F1-score: 0.505
# Class earthquake - Precision: 0.734, Recall: 0.734, F1-score: 0.731
# Class rockfall - Precision: 0.833, Recall: 0.848, F1-score: 0.839
# Class noise - Precision: 0.699, Recall: 0.806, F1-score: 0.747
# Overall Accuracy: 0.735 ± 0.032
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 125, 'max_depth': 10, 'random_state': 42}
# Class quake - Precision: 0.619, Recall: 0.446, F1-score: 0.513
# Class earthquake - Precision: 0.738, Recall: 0.730, F1-score: 0.731
# Class rockfall - Precision: 0.832, Recall: 0.848, F1-score: 0.839
# Class noise - Precision: 0.698, Recall: 0.809, F1-score: 0.748
# Overall Accuracy: 0.736 ± 0.032
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 150, 'max_depth': 10, 'random_state': 42}
# Class quake - Precision: 0.618, Recall: 0.453, F1-score: 0.517
# Class earthquake - Precision: 0.743, Recall: 0.730, F1-score: 0.734
# Class rockfall - Precision: 0.834, Recall: 0.851, F1-score: 0.841
# Class noise - Precision: 0.700, Recall: 0.808, F1-score: 0.749
# Overall Accuracy: 0.738 ± 0.033
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 175, 'max_depth': 12, 'random_state': 42}
# Class quake - Precision: 0.614, Recall: 0.450, F1-score: 0.514
# Class earthquake - Precision: 0.744, Recall: 0.728, F1-score: 0.733
# Class rockfall - Precision: 0.836, Recall: 0.852, F1-score: 0.843
# Class noise - Precision: 0.699, Recall: 0.811, F1-score: 0.750
# Overall Accuracy: 0.738 ± 0.033
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 200, 'max_depth': 15, 'random_state': 42}
# Class quake - Precision: 0.619, Recall: 0.454, F1-score: 0.518
# Class earthquake - Precision: 0.745, Recall: 0.732, F1-score: 0.735
# Class rockfall - Precision: 0.838, Recall: 0.851, F1-score: 0.843
# Class noise - Precision: 0.700, Recall: 0.812, F1-score: 0.750
# Overall Accuracy: 0.740 ± 0.033
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 225, 'max_depth': 17, 'random_state': 42}
# Class quake - Precision: 0.620, Recall: 0.453, F1-score: 0.518
# Class earthquake - Precision: 0.743, Recall: 0.732, F1-score: 0.734
# Class rockfall - Precision: 0.840, Recall: 0.851, F1-score: 0.844
# Class noise - Precision: 0.698, Recall: 0.812, F1-score: 0.749
# Overall Accuracy: 0.739 ± 0.033
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 250, 'max_depth': 20, 'random_state': 42}
# Class quake - Precision: 0.616, Recall: 0.460, F1-score: 0.521
# Class earthquake - Precision: 0.744, Recall: 0.729, F1-score: 0.734
# Class rockfall - Precision: 0.841, Recall: 0.850, F1-score: 0.844
# Class noise - Precision: 0.700, Recall: 0.812, F1-score: 0.750
# Overall Accuracy: 0.740 ± 0.033
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 300, 'max_depth': 22, 'random_state': 42}
# Class quake - Precision: 0.613, Recall: 0.463, F1-score: 0.522
# Class earthquake - Precision: 0.746, Recall: 0.729, F1-score: 0.735
# Class rockfall - Precision: 0.840, Recall: 0.850, F1-score: 0.844
# Class noise - Precision: 0.700, Recall: 0.810, F1-score: 0.750
# Overall Accuracy: 0.740 ± 0.033
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 350, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.612, Recall: 0.466, F1-score: 0.524
# Class earthquake - Precision: 0.750, Recall: 0.728, F1-score: 0.736
# Class rockfall - Precision: 0.840, Recall: 0.854, F1-score: 0.845
# Class noise - Precision: 0.700, Recall: 0.809, F1-score: 0.750
# Overall Accuracy: 0.741 ± 0.033
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 375, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.613, Recall: 0.466, F1-score: 0.524
# Class earthquake - Precision: 0.749, Recall: 0.729, F1-score: 0.736
# Class rockfall - Precision: 0.840, Recall: 0.852, F1-score: 0.845
# Class noise - Precision: 0.701, Recall: 0.809, F1-score: 0.750
# Overall Accuracy: 0.741 ± 0.033
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 400, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.614, Recall: 0.469, F1-score: 0.526
# Class earthquake - Precision: 0.751, Recall: 0.730, F1-score: 0.738
# Class rockfall - Precision: 0.839, Recall: 0.853, F1-score: 0.845
# Class noise - Precision: 0.703, Recall: 0.809, F1-score: 0.751
# Overall Accuracy: 0.742 ± 0.033
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 425, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.616, Recall: 0.471, F1-score: 0.528
# Class earthquake - Precision: 0.751, Recall: 0.730, F1-score: 0.737
# Class rockfall - Precision: 0.839, Recall: 0.853, F1-score: 0.845
# Class noise - Precision: 0.703, Recall: 0.809, F1-score: 0.751
# Overall Accuracy: 0.742 ± 0.033
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 450, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.617, Recall: 0.470, F1-score: 0.527
# Class earthquake - Precision: 0.749, Recall: 0.731, F1-score: 0.737
# Class rockfall - Precision: 0.840, Recall: 0.852, F1-score: 0.845
# Class noise - Precision: 0.704, Recall: 0.809, F1-score: 0.752
# Overall Accuracy: 0.742 ± 0.033
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 475, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.618, Recall: 0.470, F1-score: 0.528
# Class earthquake - Precision: 0.751, Recall: 0.731, F1-score: 0.738
# Class rockfall - Precision: 0.839, Recall: 0.854, F1-score: 0.845
# Class noise - Precision: 0.704, Recall: 0.809, F1-score: 0.752
# Overall Accuracy: 0.742 ± 0.033
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 500, 'max_depth': 25, 'random_state': 42}
# Class quake - Precision: 0.618, Recall: 0.468, F1-score: 0.527
# Class earthquake - Precision: 0.748, Recall: 0.731, F1-score: 0.737
# Class rockfall - Precision: 0.839, Recall: 0.853, F1-score: 0.845
# Class noise - Precision: 0.704, Recall: 0.809, F1-score: 0.751
# Overall Accuracy: 0.742 ± 0.033
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 500, 'max_depth': 20, 'random_state': 42}
# Class quake - Precision: 0.618, Recall: 0.468, F1-score: 0.527
# Class earthquake - Precision: 0.748, Recall: 0.731, F1-score: 0.737
# Class rockfall - Precision: 0.839, Recall: 0.853, F1-score: 0.845
# Class noise - Precision: 0.704, Recall: 0.809, F1-score: 0.751
# Overall Accuracy: 0.742 ± 0.033
# --------------------------------------------------
# Testing RF with parameters: {'n_estimators': 500, 'max_depth': 30, 'random_state': 42}
# Class quake - Precision: 0.618, Recall: 0.468, F1-score: 0.527
# Class earthquake - Precision: 0.748, Recall: 0.731, F1-score: 0.737
# Class rockfall - Precision: 0.839, Recall: 0.853, F1-score: 0.845
# Class noise - Precision: 0.704, Recall: 0.809, F1-score: 0.751
# Overall Accuracy: 0.742 ± 0.033
# --------------------------------------------------
